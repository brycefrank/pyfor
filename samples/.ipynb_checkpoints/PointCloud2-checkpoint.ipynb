# %% [markdown]
# Append path to pyfor module

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../pyfor'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pointcloud2

# %%
tile=pointcloud2.Cloud("data/NEON_D03_OSBS_DP1_405000_3276000_classified_point_cloud.laz")

# %% [markdown]
# ## Point cloud statistics

# %%
print("Number of points: %d" % tile.las.header.count)
# Out:
# Number of points: 2912035

# %% [markdown]
# ## 2D plot

# %%
tile.plot()
